# %% [markdown]
# # This Jupyter Notebook for VO data discovery
#
# I experiment here with the **PyVO** library and ways to discover and download astronomical data.

# %% [markdown]
# Let's start by exploring **scanned photographic plates** via the **ObsCore** table and retrieving them in bulk using **DataLink** services.

# %%
print("Hello World!")
import pyvo
# Out:
# Hello World!

# %% [markdown]
# Connect to the GAVO TAP service

# %%
tap_url = "http://dc.g-vo.org/tap"
tap_service = pyvo.dal.TAPService(tap_url)
tap_service
# Out:
# TAPService(baseurl : 'http://dc.g-vo.org/tap', description : 'None')

# %% [markdown]
# Query the ObsCore table for images containing our source with specified equatorial coordinates

# %%
query = """
SELECT *
FROM ivoa.Obscore
WHERE dataproduct_type = 'image'
  AND CONTAINS(
        POINT('ICRS', 156.01124674021, 48.14753874736),
        s_region
      ) = 1
  AND NOT obs_collection LIKE '%RASS%'
ORDER BY t_min
"""
result = tap_service.search(query)

# %% [markdown]
# Convert TAPResults into a table and add ISO datetime columns
# Convert 't_min' and 't_max' from MJD to ISO datetime
# Save the resulting table

# %%
from astropy.time import Time

table = result.to_table()
table["date_min"] = Time(table['t_min'], format="mjd").isot
table["date_max"] = Time(table['t_max'], format="mjd").isot
table.write("table.txt", format="ascii", overwrite=True)
table.show_in_notebook()
# Out:
# /home/voz/projects/UPJS/DataDiscovery/.venv/lib/python3.11/site-packages/erfa/core.py:133: ErfaWarning: ERFA function "d2dtf" yielded 151 of "dubious year (Note 5)"
#   warn(f'ERFA function "{func_name}" yielded {wmsg}', ErfaWarning)
# DataGrid(auto_fit_params={'area': 'all', 'padding': 30, 'numCols': None}, corner_renderer=None, default_render…

# %%
# table.show_in_notebook()
# table.show_in_browser()

# tt = Time(table['t_min'], format='mjd')
table['t_min_ym'] = Time(table['t_min'], format='mjd').strftime("%Y-%m")
table['date_min','t_min_ym']
# table["scan_id"] = [obs_id.split('/')[-1] for obs_id in table['obs_id']]
table["scan_id"] = [access_url.split('/')[-1] for access_url in table['access_url']]
# table["t_min_ym", "scan_id", "obs_collection", "access_url"].write("table_dates.txt", format="ascii", overwrite=True)
table["t_min_ym", "scan_id"].write("table_dates.txt", format="ascii", overwrite=True)
# table.show_in_browser()
# Out:
# /home/voz/projects/UPJS/DataDiscovery/.venv/lib/python3.11/site-packages/erfa/core.py:133: ErfaWarning: ERFA function "d2dtf" yielded 151 of "dubious year (Note 5)"
#   warn(f'ERFA function "{func_name}" yielded {wmsg}', ErfaWarning)

# %%
from pathlib import Path

def build_filename(download_dir_name, content_type, url, suffix=''):
    download_dir = Path(download_dir_name)
    download_dir.mkdir(parents=True, exist_ok=True)
    if content_type == "application/fits":
        ext = ".fits"
    elif content_type.startswith("image/"):
        ext = "." + content_type.split("/", 1)[1]
    else:
        ext = ""
    path = Path(Path(url).name + "_" + suffix)
    if ext and path.suffix.lower() != ext:
        path = path.with_suffix(ext)

    return download_dir / path

# %% [markdown]
# Download DataLink results for the dataset with the specified semantics

# %%
import requests

def download_by_semantics(datalink, suffix='', semantics='#this', download_dir_name='plates'):
    dl_list = list(datalink.bysemantics(semantics))
    if len(dl_list) == 0:
        print(datalink, semantics)
        print('is empty, skipping')
        raise ValueError("datalink table is empty, skipping")
    link = list(datalink.bysemantics(semantics))[0]
    url = link["access_url"]
    content_type = link["content_type"].lower()

    filename = build_filename(download_dir_name=download_dir_name, content_type=content_type, url=url, suffix=suffix)
    if filename.exists():
        print(f"Skipping {filename.name} (already exists)")
        return

    print(f"Downloading {filename} ...")
    r = requests.get(url)
    r.raise_for_status()  # stop if error
    with open(filename, "wb") as f:
        f.write(r.content)
    print(f"{filename} saved")

# %% [markdown]
# Apply *download_by_semantics* to retrieve preview images.
# We attempt to download the #preview-image semantics first, expecting higher quality

# %%
from astropy.time import Time

for res in list(result)[:5]:
    # print(help(r))
    dl = res.getdatalink()
    jyear = Time(res["t_min"], format="mjd").jyear
    jyear_str = f'{jyear:.0f}'
    try:
        download_by_semantics(dl, semantics='#preview-image', suffix=jyear_str)
    except (requests.exceptions.HTTPError, ValueError) as e:
        print(e)
        print(f'Downloading {dl} by semantics #preview-image failed')
        try:
            download_by_semantics(dl, semantics='#preview', suffix=jyear_str)
        except requests.exceptions.HTTPError as e:
            print(f'Downloading {dl} by semantics #preview failed')
# Out:
# Skipping b01941_1888.jpeg (already exists)
# Skipping i00601_1890.jpeg (already exists)
# Skipping i00811_1890.jpeg (already exists)
# Skipping i01126_1890.jpeg (already exists)
# Skipping i02347_1891.jpeg (already exists)

# %% [markdown]
# Download #this (most likely a downsampled FITS image)

# %%
from astropy.time import Time

for res in list(result)[:3]:
    dl = res.getdatalink()
    jyear = Time(res["t_min"], format="mjd").jyear
    jyear_str = f'{jyear:.0f}'
    try:
        download_by_semantics(dl, semantics='#this', suffix=jyear_str)
    except (requests.exceptions.HTTPError, ValueError) as e:
        print(e)
        print(f'Downloading {dl} by semantics #this failed')
# Out:
# Skipping b01941_1888.fits (already exists)
# Skipping i00601_1890.fits (already exists)
# Skipping i00811_1890.fits (already exists)

# %% [markdown]
# Cut out a square region around FOI

# %%
from astropy.nddata import Cutout2D
help(Cutout2D)
# Out:
# Help on class Cutout2D in module astropy.nddata.utils:
#
# class Cutout2D(builtins.object)
#  |  Cutout2D(data, position, size, wcs=None, mode='trim', fill_value=nan, copy=False, *, limit_rounding_method=<ufunc 'ceil'>)
#  |
#  |  Create a cutout object from a 2D array.
#  |
#  |  The returned object will contain a 2D cutout array.  If
#  |  ``copy=False`` (default), the cutout array is a view into the
#  |  original ``data`` array, otherwise the cutout array will contain a
#  |  copy of the original data.
#  |
#  |  If a `~astropy.wcs.WCS` object is input, then the returned object
#  |  will also contain a copy of the original WCS, but updated for the
#  |  cutout array.
#  |
#  |  For example usage, see :ref:`astropy:cutout_images`.
#  |
#  |  .. warning::
#  |
#  |      The cutout WCS object does not currently handle cases where the
#  |      input WCS object contains distortion lookup tables described in
#  |      the `FITS WCS distortion paper
#  |      <https://www.atnf.csiro.au/people/mcalabre/WCS/dcs_20040422.pdf>`__.
#  |
#  |  Parameters
#  |  ----------
#  |  data : ndarray
#  |      The 2D data array from which to extract the cutout array.
#  |
#  |  position : tuple or `~astropy.coordinates.SkyCoord`
#  |      The position of the cutout array's center with respect to
#  |      the ``data`` array.  The position can be specified either as
#  |      a ``(x, y)`` tuple of pixel coordinates or a
#  |      `~astropy.coordinates.SkyCoord`, in which case ``wcs`` is a
#  |      required input.
#  |
#  |  size : int, array-like, or `~astropy.units.Quantity`
#  |      The size of the cutout array along each axis.  If ``size``
#  |      is a scalar number or a scalar `~astropy.units.Quantity`,
#  |      then a square cutout of ``size`` will be created.  If
#  |      ``size`` has two elements, they should be in ``(ny, nx)``
#  |      order.  Scalar numbers in ``size`` are assumed to be in
#  |      units of pixels.  ``size`` can also be a
#  |      `~astropy.units.Quantity` object or contain
#  |      `~astropy.units.Quantity` objects.  Such
#  |      `~astropy.units.Quantity` objects must be in pixel or
#  |      angular units.  For all cases, ``size`` will be converted to
#  |      an integer number of pixels, rounding the nearest
#  |      integer.  See the ``mode`` keyword for additional details on
#  |      the final cutout size.
#  |
#  |      .. note::
#  |          If ``size`` is in angular units, the cutout size is
#  |          converted to pixels using the pixel scales along each
#  |          axis of the image at the ``CRPIX`` location.  Projection
#  |          and other non-linear distortions are not taken into
#  |          account.
#  |
#  |  wcs : `~astropy.wcs.WCS`, optional
#  |      A WCS object associated with the input ``data`` array.  If
#  |      ``wcs`` is not `None`, then the returned cutout object will
#  |      contain a copy of the updated WCS for the cutout data array.
#  |
#  |  mode : {'trim', 'partial', 'strict'}, optional
#  |      The mode used for creating the cutout data array.  For the
#  |      ``'partial'`` and ``'trim'`` modes, a partial overlap of the
#  |      cutout array and the input ``data`` array is sufficient.
#  |      For the ``'strict'`` mode, the cutout array has to be fully
#  |      contained within the ``data`` array, otherwise an
#  |      `~astropy.nddata.utils.PartialOverlapError` is raised.   In
#  |      all modes, non-overlapping arrays will raise a
#  |      `~astropy.nddata.utils.NoOverlapError`.  In ``'partial'``
#  |      mode, positions in the cutout array that do not overlap with
#  |      the ``data`` array will be filled with ``fill_value``.  In
#  |      ``'trim'`` mode only the overlapping elements are returned,
#  |      thus the resulting cutout array may be smaller than the
#  |      requested ``shape``.
#  |
#  |  fill_value : float or int, optional
#  |      If ``mode='partial'``, the value to fill pixels in the
#  |      cutout array that do not overlap with the input ``data``.
#  |      ``fill_value`` must have the same ``dtype`` as the input
#  |      ``data`` array.
#  |
#  |  copy : bool, optional
#  |      If `False` (default), then the cutout data will be a view
#  |      into the original ``data`` array.  If `True`, then the
#  |      cutout data will hold a copy of the original ``data`` array.
#  |
#  |  limit_rounding_method : callable
#  |      The rounding method when calculating the minimum and maximum pixel indices.
#  |      This must be a callable function. Examples: `~numpy.ceil`, `~numpy.floor`,
#  |      `~numpy.round`. Default is `~numpy.ceil`.
#  |
#  |  Attributes
#  |  ----------
#  |  data : 2D `~numpy.ndarray`
#  |      The 2D cutout array.
#  |
#  |  shape : (2,) tuple
#  |      The ``(ny, nx)`` shape of the cutout array.
#  |
#  |  shape_input : (2,) tuple
#  |      The ``(ny, nx)`` shape of the input (original) array.
#  |
#  |  input_position_cutout : (2,) tuple
#  |      The (unrounded) ``(x, y)`` position with respect to the cutout
#  |      array.
#  |
#  |  input_position_original : (2,) tuple
#  |      The original (unrounded) ``(x, y)`` input position (with respect
#  |      to the original array).
#  |
#  |  slices_original : (2,) tuple of slice object
#  |      A tuple of slice objects for the minimal bounding box of the
#  |      cutout with respect to the original array.  For
#  |      ``mode='partial'``, the slices are for the valid (non-filled)
#  |      cutout values.
#  |
#  |  slices_cutout : (2,) tuple of slice object
#  |      A tuple of slice objects for the minimal bounding box of the
#  |      cutout with respect to the cutout array.  For
#  |      ``mode='partial'``, the slices are for the valid (non-filled)
#  |      cutout values.
#  |
#  |  xmin_original, ymin_original, xmax_original, ymax_original : float
#  |      The minimum and maximum ``x`` and ``y`` indices of the minimal
#  |      rectangular region of the cutout array with respect to the
#  |      original array.  For ``mode='partial'``, the bounding box
#  |      indices are for the valid (non-filled) cutout values.  These
#  |      values are the same as those in `bbox_original`.
#  |
#  |  xmin_cutout, ymin_cutout, xmax_cutout, ymax_cutout : float
#  |      The minimum and maximum ``x`` and ``y`` indices of the minimal
#  |      rectangular region of the cutout array with respect to the
#  |      cutout array.  For ``mode='partial'``, the bounding box indices
#  |      are for the valid (non-filled) cutout values.  These values are
#  |      the same as those in `bbox_cutout`.
#  |
#  |  wcs : `~astropy.wcs.WCS` or None
#  |      A WCS object associated with the cutout array if a ``wcs``
#  |      was input.
#  |
#  |  Examples
#  |  --------
#  |  >>> import numpy as np
#  |  >>> from astropy.nddata.utils import Cutout2D
#  |  >>> from astropy import units as u
#  |  >>> data = np.arange(20.).reshape(5, 4)
#  |  >>> cutout1 = Cutout2D(data, (2, 2), (3, 3))
#  |  >>> print(cutout1.data)  # doctest: +FLOAT_CMP
#  |  [[ 5.  6.  7.]
#  |   [ 9. 10. 11.]
#  |   [13. 14. 15.]]
#  |
#  |  >>> print(cutout1.center_original)
#  |  (2.0, 2.0)
#  |  >>> print(cutout1.center_cutout)
#  |  (1.0, 1.0)
#  |  >>> print(cutout1.origin_original)
#  |  (1, 1)
#  |
#  |  >>> cutout2 = Cutout2D(data, (2, 2), 3)
#  |  >>> print(cutout2.data)  # doctest: +FLOAT_CMP
#  |  [[ 5.  6.  7.]
#  |   [ 9. 10. 11.]
#  |   [13. 14. 15.]]
#  |
#  |  >>> size = u.Quantity([3, 3], u.pixel)
#  |  >>> cutout3 = Cutout2D(data, (0, 0), size)
#  |  >>> print(cutout3.data)  # doctest: +FLOAT_CMP
#  |  [[0. 1.]
#  |   [4. 5.]]
#  |
#  |  >>> cutout4 = Cutout2D(data, (0, 0), (3 * u.pixel, 3))
#  |  >>> print(cutout4.data)  # doctest: +FLOAT_CMP
#  |  [[0. 1.]
#  |   [4. 5.]]
#  |
#  |  >>> cutout5 = Cutout2D(data, (0, 0), (3, 3), mode='partial')
#  |  >>> print(cutout5.data)  # doctest: +FLOAT_CMP
#  |  [[nan nan nan]
#  |   [nan  0.  1.]
#  |   [nan  4.  5.]]
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, data, position, size, wcs=None, mode='trim', fill_value=nan, copy=False, *, limit_rounding_method=<ufunc 'ceil'>)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  plot_on_original(self, ax=None, fill=False, **kwargs)
#  |      Plot the cutout region on a matplotlib Axes instance.
#  |
#  |      Parameters
#  |      ----------
#  |      ax : `matplotlib.axes.Axes` instance, optional
#  |          If `None`, then the current `matplotlib.axes.Axes` instance
#  |          is used.
#  |
#  |      fill : bool, optional
#  |          Set whether to fill the cutout patch.  The default is
#  |          `False`.
#  |
#  |      kwargs : optional
#  |          Any keyword arguments accepted by `matplotlib.patches.Patch`.
#  |
#  |      Returns
#  |      -------
#  |      ax : `matplotlib.axes.Axes` instance
#  |          The matplotlib Axes instance constructed in the method if
#  |          ``ax=None``.  Otherwise the output ``ax`` is the same as the
#  |          input ``ax``.
#  |
#  |  to_cutout_position(self, original_position)
#  |      Convert an ``(x, y)`` position in the original large array to
#  |      the ``(x, y)`` position in the cutout array.
#  |
#  |      Parameters
#  |      ----------
#  |      original_position : tuple
#  |          The ``(x, y)`` pixel position in the original large array.
#  |
#  |      Returns
#  |      -------
#  |      cutout_position : tuple
#  |          The corresponding ``(x, y)`` pixel position in the cutout
#  |          array.
#  |
#  |      See Also
#  |      --------
#  |      to_original_position
#  |
#  |  to_original_position(self, cutout_position)
#  |      Convert an ``(x, y)`` position in the cutout array to the original
#  |      ``(x, y)`` position in the original large array.
#  |
#  |      Parameters
#  |      ----------
#  |      cutout_position : tuple
#  |          The ``(x, y)`` pixel position in the cutout array.
#  |
#  |      Returns
#  |      -------
#  |      original_position : tuple
#  |          The corresponding ``(x, y)`` pixel position in the original
#  |          large array.
#  |
#  |      See Also
#  |      --------
#  |      to_cutout_position
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  bbox_cutout
#  |      The bounding box ``((ymin, ymax), (xmin, xmax))`` of the minimal
#  |      rectangular region of the cutout array with respect to the
#  |      cutout array.  For ``mode='partial'``, the bounding box indices
#  |      are for the valid (non-filled) cutout values.
#  |
#  |  bbox_original
#  |      The bounding box ``((ymin, ymax), (xmin, xmax))`` of the minimal
#  |      rectangular region of the cutout array with respect to the
#  |      original array.  For ``mode='partial'``, the bounding box
#  |      indices are for the valid (non-filled) cutout values.
#  |
#  |  center_cutout
#  |      The central ``(x, y)`` position of the cutout array with respect
#  |      to the cutout array.  For ``mode='partial'``, the central
#  |      position is calculated for the valid (non-filled) cutout values.
#  |
#  |  center_original
#  |      The central ``(x, y)`` position of the cutout array with respect
#  |      to the original array.  For ``mode='partial'``, the central
#  |      position is calculated for the valid (non-filled) cutout values.
#  |
#  |  origin_cutout
#  |      The ``(x, y)`` index of the origin pixel of the cutout with
#  |      respect to the cutout array.  For ``mode='partial'``, the origin
#  |      pixel is calculated for the valid (non-filled) cutout values.
#  |
#  |  origin_original
#  |      The ``(x, y)`` index of the origin pixel of the cutout with
#  |      respect to the original array.  For ``mode='partial'``, the
#  |      origin pixel is calculated for the valid (non-filled) cutout
#  |      values.
#  |
#  |  position_cutout
#  |      The ``(x, y)`` position index (rounded to the nearest pixel) in
#  |      the cutout array.
#  |
#  |  position_original
#  |      The ``(x, y)`` position index (rounded to the nearest pixel) in
#  |      the original array.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
import astropy.units as u
from astropy.io import fits
from astropy.nddata import Cutout2D
from astropy.coordinates import SkyCoord
from astropy.wcs import WCS
from pathlib import Path

ra_deg_tmp = 156.01124674021
dec_deg_tmp = 48.14753874736
radius_deg_tmp = 10/60
position = SkyCoord(ra= ra_deg_tmp* u.deg, dec= dec_deg_tmp * u.deg, frame="icrs")
size = radius_deg_tmp * 2 * u.deg
# fits_path = Path('plates/applause/HS01338_y.fits')
fits_path = Path('plates/applause/AG03170_y.fits')
with fits.open(fits_path) as hdul:
    hdu = hdul[0]
    data = hdu.data
    wcs = WCS(hdu.header)

cutout = Cutout2D(
    data,
    position=position,
    size=size,
    wcs=wcs,
    mode="trim"
    )
new_hdu = fits.PrimaryHDU(data=cutout.data, header=cutout.wcs.to_header())
out_path = fits_path.with_name(fits_path.stem + "_cut.fits")
new_hdu.writeto(out_path, overwrite=True)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 36305.845104 from DATE-OBS.
# Set MJD-AVG to 36305.850301 from DATE-AVG.
# Set MJD-END to 36305.855498 from DATE-END'. [astropy.wcs.wcs]

# %% [markdown]
# Here we will touch **SODA** interface.
# Quite often we do not need to download the **whole** image. Instead, we can cut out the FOI **on the server side**.
#
# By the way, datacenters may provide a downsampled FITS file under the semantics #this, hiding the full-resolution image under the semantics #coderived. This is reasonable from the datacenter point of view, as it saves resources from occasional downloads.
#
# However, when searching for transients or performing photometry, we do need a *high-quality* image, even though we usually do not require the *whole* plate.

# %% [markdown]
# Let's take a closer view at the first datalink table from our query results

# %%
res_first = list(result)[0]
dl = res_first.getdatalink()
t = dl.to_table()
t.show_in_notebook()
t
# Out:
# <Table length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-AG/AG03152_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-AG/AG03152_y.fits ...

# %% [markdown]
# We are lucky: this datalink contains something with #proc semantics; **descriptions** says, that this is precisely what we need. Unfortunately, we are not able to choose cutout size time, as mentioned in the description, but this is not a case for all datalinks (indeed, some of them do not provide users with SODA interface at all)
#
# We are lucky: this DataLink contains entries with the #proc semantics; the **description** indicates that this is exactly what we need.
#
# Unfortunately, we cannot choose the cutout size in this case, as mentioned in the description. However, this does not relate to all DataLinks — some provide this option, while others do not offer a SODA interface at all.

# %% [markdown]
# To explore the SODA service, we need to know the URL of the endpoint for submitting SODA requests (where the methods reside) and the input parameters.
# All of this we can extract from the DataLink table metadata and the DataLink table itself. Examining the corresponding VOTable (XML) helps to figure out where these things live.

# %%
[print(p) for r in dl.votable.resources for p in r.params]
from astropy.io.votable import writeto
writeto(dl.votable, "datalink.vot")
# Out:
# <PARAM ID="accessURL" arraysize="*" datatype="char" name="accessURL" ucd="meta.ref.url" value="http://dc.g-vo.org/dasch/q/dl/dlget"/>
# <PARAM ID="standardID" arraysize="*" datatype="char" name="standardID" value="ivo://ivoa.net/std/soda#sync-1.0"/>

# %% [markdown]
# Take a look at the datalink. We can extract some parameters visible in the TOPCAT "Table Parameters" window this way (I hope, PyVO provides methods to handle these details under the hood). First of all, we need to extract input parameters:

# %%
vot = dl.votable  # pyvo.dal.adhoc.DatalinkResults VOTable
input_params_tmp = {}
# Iterate over all resources
for res in vot.resources:
    # Iterate over all GROUPs in the resource
    for group_tmp in res.groups:
        if group_tmp.ID == "inputParams":
            for item_tmp in group_tmp.iter_fields_and_params():
                print(f'{item_tmp.name=}, {item_tmp.ucd=}, {item_tmp.value=}')
                print(f'{item_tmp.description=}')
                input_params_tmp[item_tmp.name] = item_tmp.value
# Out:
# item.name='ID', item.ucd='meta.id;meta.main', item.value='ivo://org.gavo.dc/~?dasch/q/i00811'
# item.description='The publisher DID of the dataset of interest'
# item.name='POS', item.ucd='phys.angArea;obs', item.value=''
# item.description='SIAv2-compatible cutout specification'

# %% [markdown]
# SODA endpoint is here:

# %%
proc_link_tmp = next(dl.bysemantics("#proc"))

# %% [markdown]
# Try to submit a request to the SODA

# %%
soda_url_tmp = proc_link_tmp.access_url
contents_type_tmp = proc_link_tmp.content_type
ra_deg_tmp = 156.01124674021
dec_deg_tmp = 48.14753874736
radius_deg_tmp = 0.5
params_tmp = {
    "ID": input_params_tmp["ID"],
    "POS": f'CIRCLE {ra_deg_tmp} {dec_deg_tmp} {radius_deg_tmp}'
}
r = requests.get(soda_url_tmp, params=params_tmp)
r
# Out:
# <Response [200]>

# %% [markdown]
# Check and save result:

# %%
r.raise_for_status()
content_type_tmp = r.headers['Content-Type']
with open('tmp.tmp', "wb") as f:
    f.write(r.content)
    print(f'file is ready')

# %% [markdown]
# Gathering everything together:
# **The Algorithm**:
# 1. Try to download a cutout around the **FOI** via SODA.
# 2. If that fails, download the full-resolution FITS image (the dataset with `#this` semantics).
# 3. If that fails, download the dataset with `#preview-image` semantics.
# 4. If that fails, download the dataset with `#preview` semantics.
# 5. If all else fails… well, screw it.

# %%
def download_cutout(dtl, ra_deg, dec_deg, radius_deg):
    proc_link = next(dtl.bysemantics("#proc"))
    input_params = {}
    for resource in dtl.votable.resources:
    # Iterate over all GROUPs in the resource
        for group in resource.groups:
            if group.ID == "inputParams":
                for item in group.iter_fields_and_params():
                    input_params[item.name] = item.value

    soda_url = proc_link.access_url
    contents_type = proc_link.content_type

    params = {
        "ID": input_params["ID"],
        "POS": f'CIRCLE {ra_deg} {dec_deg} {radius_deg}'
    }

    print(f'cutout_{ra_deg:.0f}_{dec_deg:.0f}')
    cutout_name = build_filename(download_dir_name="plates", content_type="application/fits", url=input_params["ID"], suffix=f'cutout_{ra_deg:.0f}_{dec_deg:.0f}')
    print(f"Downloading {cutout_name} ...")
    if cutout_name.exists():
        print(f"Skipping {cutout_name.name} (already exists)")
        return
    r = requests.get(soda_url, params=params)
    r.raise_for_status()
    content_type = r.headers['Content-Type']
    cutout_name = build_filename(download_dir_name="plates", content_type="application/fits", url=input_params["ID"], suffix=f'cutout_{ra_deg:.0f}_{dec_deg:.0f}')
    with open(cutout_name, "wb") as f:
        f.write(r.content)
        print(f'{cutout_name} is ready')

# %%
from astropy.time import Time

foi_ra_deg = 156.01124674021
foi_dec_deg = 48.14753874736
foi_radius_deg = 0.5
result_list = list(result)

for res in result:
# if True:
#     res = result_list[100]
    dl = res.getdatalink()
    t = dl.to_table()
    t.show_in_notebook()
    t
    jyear = Time(res["t_min"], format="mjd").jyear
    jyear_str = f'{jyear:.0f}'

    # Try cutout:
    try:
        download_cutout(dl, foi_ra_deg, foi_dec_deg, foi_radius_deg)
    except (requests.exceptions.HTTPError, StopIteration, ValueError):
        print("Datalink do not provide #proc")
        # Well, try to get the whole image
        print("Trying to download whole fits image by #this semantics")
        try:
            download_by_semantics(dl, semantics='#this', suffix=jyear_str)
        except (requests.exceptions.HTTPError, StopIteration, ValueError) as e:
            print(e)
            print(f'Downloading {dl} by semantics #this failed')
            # We still have alternatives
            print('Trying to download preview in the best quality with #peview-image semantics ')
            try:
                download_by_semantics(dl, semantics='#preview-image', suffix=jyear_str)
            except (requests.exceptions.HTTPError, StopIteration, ValueError) as e:
                print(e)
                print(f'Downloading {dl} by semantics #preview-image failed')
                # I doubt we will be happy with thumbnails, but seems, this is a last chance
                try:
                    download_by_semantics(dl, semantics='#preview', suffix=jyear_str)
                except (requests.exceptions.HTTPError, StopIteration, ValueError) as e:
                    print(f'Downloading {dl} by semantics #preview failed')
                    # Well, to hell with it, let's move on
                    # continue
# Out:
# cutout_156_48
# Skipping b01941_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i00601_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i00811_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i01126_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i02347_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i05998_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i05999_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i06043_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i06162_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i08266_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i08359_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i08382_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i08395_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i12127_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i12306_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i12790_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i14024_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i14208_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i14897_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i15131_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i20598_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i20650_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i21896_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i22052_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i22053_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i22483_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i24795_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i24798_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i25122_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i26210_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i26284_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i26671_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i28639_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i30110_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i30124_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping a06352_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping a06369_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i34541_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i35177_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping md02198_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping md02397_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping md04648_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping mc05245_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping mc07637_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping mc07764_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping mc08088_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping mf00621_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping mf01942_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping mf01944_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping mf02447_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i39575_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i39576_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping mc16500_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping mc16501_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping mc17170_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping B4515b.fits (already exists)
# cutout_156_48
# Skipping B4514a.fits (already exists)
# cutout_156_48
# Skipping i40780_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i40812_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i41937_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i43223_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i43224_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping mc20550_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping mc20673_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i43417_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping mc20704_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i44450_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i44532_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i45259_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i45293_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i45339_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i45341_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i45352_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping mc22481_cutout_156_48.fits (already exists)
# Datalink do not provide #proc
# Trying to download whole fits image by #this semantics
# Downloading plates/LA02273_y.fits ...
# 404 Client Error: Not Found for url: https://www.plate-archive.org/files/DR3/scans/HAM-LA/LA02273_y.fits
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02273_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02273_y.fits ... by semantics #this failed
# Trying to download preview in the best quality with #peview-image semantics
# <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02273_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02273_y.fits ... #preview-image
# is empty, skipping
# datalink table is empty, skipping
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02273_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02273_y.fits ... by semantics #preview-image failed
# Skipping LA02273_pre.jpg_1928 (already exists)
# Datalink do not provide #proc
# Trying to download whole fits image by #this semantics
# Downloading plates/LA02296_y.fits ...
# 404 Client Error: Not Found for url: https://www.plate-archive.org/files/DR3/scans/HAM-LA/LA02296_y.fits
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02296_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02296_y.fits ... by semantics #this failed
# Trying to download preview in the best quality with #peview-image semantics
# <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02296_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02296_y.fits ... #preview-image
# is empty, skipping
# datalink table is empty, skipping
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02296_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02296_y.fits ... by semantics #preview-image failed
# Skipping LA02296_pre.jpg_1928 (already exists)
# Datalink do not provide #proc
# Trying to download whole fits image by #this semantics
# Downloading plates/LA02298_y.fits ...
# 404 Client Error: Not Found for url: https://www.plate-archive.org/files/DR3/scans/HAM-LA/LA02298_y.fits
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02298_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02298_y.fits ... by semantics #this failed
# Trying to download preview in the best quality with #peview-image semantics
# <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02298_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02298_y.fits ... #preview-image
# is empty, skipping
# datalink table is empty, skipping
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02298_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02298_y.fits ... by semantics #preview-image failed
# Skipping LA02298_pre.jpg_1928 (already exists)
# Datalink do not provide #proc
# Trying to download whole fits image by #this semantics
# Downloading plates/LA02300_y.fits ...
# 404 Client Error: Not Found for url: https://www.plate-archive.org/files/DR3/scans/HAM-LA/LA02300_y.fits
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02300_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02300_y.fits ... by semantics #this failed
# Trying to download preview in the best quality with #peview-image semantics
# <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02300_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02300_y.fits ... #preview-image
# is empty, skipping
# datalink table is empty, skipping
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02300_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02300_y.fits ... by semantics #preview-image failed
# Skipping LA02300_pre.jpg_1928 (already exists)
# Datalink do not provide #proc
# Trying to download whole fits image by #this semantics
# Downloading plates/LA02303_y.fits ...
# 404 Client Error: Not Found for url: https://www.plate-archive.org/files/DR3/scans/HAM-LA/LA02303_y.fits
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02303_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02303_y.fits ... by semantics #this failed
# Trying to download preview in the best quality with #peview-image semantics
# <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02303_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02303_y.fits ... #preview-image
# is empty, skipping
# datalink table is empty, skipping
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02303_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA02303_y.fits ... by semantics #preview-image failed
# Skipping LA02303_pre.jpg_1928 (already exists)
# cutout_156_48
# Skipping mc23991_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping G8237.fits (already exists)
# cutout_156_48
# Skipping G8238.fits (already exists)
# cutout_156_48
# Skipping G8239.fits (already exists)
# cutout_156_48
# Skipping G8244.fits (already exists)
# cutout_156_48
# Skipping G8245.fits (already exists)
# Datalink do not provide #proc
# Trying to download whole fits image by #this semantics
# Downloading plates/LA04038_y.fits ...
# 404 Client Error: Not Found for url: https://www.plate-archive.org/files/DR3/scans/HAM-LA/LA04038_y.fits
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA04038_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA04038_y.fits ... by semantics #this failed
# Trying to download preview in the best quality with #peview-image semantics
# <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA04038_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA04038_y.fits ... #preview-image
# is empty, skipping
# datalink table is empty, skipping
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA04038_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA04038_y.fits ... by semantics #preview-image failed
# Skipping LA04038_pre.jpg_1933 (already exists)
# cutout_156_48
# Skipping md27142_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping mc27142_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping ma04158_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i53040_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping i53265_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping ee00741_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping ee00742_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping ee00743_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping ir00412_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping ee00770_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping ma04940_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping ma05051_cutout_156_48.fits (already exists)
# cutout_156_48
# Skipping ma05158_cutout_156_48.fits (already exists)
# Datalink do not provide #proc
# Trying to download whole fits image by #this semantics
# Downloading plates/LA04795_y.fits ...
# 404 Client Error: Not Found for url: https://www.plate-archive.org/files/DR3/scans/HAM-LA/LA04795_y.fits
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA04795_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA04795_y.fits ... by semantics #this failed
# Trying to download preview in the best quality with #peview-image semantics
# <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA04795_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA04795_y.fits ... #preview-image
# is empty, skipping
# datalink table is empty, skipping
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA04795_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-LA/LA04795_y.fits ... by semantics #preview-image failed
# Skipping LA04795_pre.jpg_1937 (already exists)
# cutout_156_48
# Datalink do not provide #proc
# Trying to download whole fits image by #this semantics
# Skipping ir01358_1937.fits (already exists)
# cutout_156_48
# Datalink do not provide #proc
# Trying to download whole fits image by #this semantics
# Downloading plates/ir01428_1937.fits ...
# plates/ir01428_1937.fits saved
# cutout_156_48
# plates/i55220_cutout_156_48.fits is ready
# cutout_156_48
# plates/i55236_cutout_156_48.fits is ready
# cutout_156_48
# plates/md29265_cutout_156_48.fits is ready
# cutout_156_48
# plates/md29278_cutout_156_48.fits is ready
# cutout_156_48
# plates/md29420_cutout_156_48.fits is ready
# cutout_156_48
# plates/mc29420_cutout_156_48.fits is ready
# cutout_156_48
# plates/md29485_cutout_156_48.fits is ready
# cutout_156_48
# plates/ir02538_cutout_156_48.fits is ready
# cutout_156_48
# plates/md29932_cutout_156_48.fits is ready
# cutout_156_48
# plates/md29961_cutout_156_48.fits is ready
# cutout_156_48
# plates/mc29961_cutout_156_48.fits is ready
# cutout_156_48
# plates/md30078_cutout_156_48.fits is ready
# cutout_156_48
# plates/md30727_cutout_156_48.fits is ready
# cutout_156_48
# plates/md30740_cutout_156_48.fits is ready
# cutout_156_48
# plates/mc30740_cutout_156_48.fits is ready
# cutout_156_48
# plates/ma08128_cutout_156_48.fits is ready
# cutout_156_48
# plates/ir03640_cutout_156_48.fits is ready
# cutout_156_48
# plates/ir03642_cutout_156_48.fits is ready
# cutout_156_48
# plates/ir03657_cutout_156_48.fits is ready
# cutout_156_48
# plates/ir03659_cutout_156_48.fits is ready
# cutout_156_48
# plates/ir03669_cutout_156_48.fits is ready
# cutout_156_48
# plates/ir03671_cutout_156_48.fits is ready
# cutout_156_48
# plates/ir03684_cutout_156_48.fits is ready
# cutout_156_48
# plates/ir03744_cutout_156_48.fits is ready
# cutout_156_48
# plates/ir03765_cutout_156_48.fits is ready
# cutout_156_48
# plates/ir03801_cutout_156_48.fits is ready
# cutout_156_48
# plates/ir03806_cutout_156_48.fits is ready
# cutout_156_48
# plates/ir03815_cutout_156_48.fits is ready
# cutout_156_48
# plates/ir03825_cutout_156_48.fits is ready
# cutout_156_48
# plates/md31220_cutout_156_48.fits is ready
# cutout_156_48
# plates/ir04556_cutout_156_48.fits is ready
# cutout_156_48
# plates/ir04557_cutout_156_48.fits is ready
# cutout_156_48
# plates/mc31307_cutout_156_48.fits is ready
# cutout_156_48
# plates/ir04619_cutout_156_48.fits is ready
# cutout_156_48
# plates/ir04759_cutout_156_48.fits is ready
# cutout_156_48
# plates/ir04770_cutout_156_48.fits is ready
# cutout_156_48
# plates/mc31858_cutout_156_48.fits is ready
# cutout_156_48
# plates/ir05655_cutout_156_48.fits is ready
# cutout_156_48
# plates/ma09305_cutout_156_48.fits is ready
# cutout_156_48
# plates/i58581_cutout_156_48.fits is ready
# cutout_156_48
# plates/i58732_cutout_156_48.fits is ready
# cutout_156_48
# plates/ir07632_cutout_156_48.fits is ready
# cutout_156_48
# plates/ir09969_cutout_156_48.fits is ready
# cutout_156_48
# plates/ir11057_cutout_156_48.fits is ready
# cutout_156_48
# plates/B7306b.fits is ready
# cutout_156_48
# plates/j03860_cutout_156_48.fits is ready
# Datalink do not provide #proc
# Trying to download whole fits image by #this semantics
# Downloading plates/AG03139_y.fits ...
# 404 Client Error: Not Found for url: https://www.plate-archive.org/files/DR3/scans/HAM-AG/AG03139_y.fits
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-AG/AG03139_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-AG/AG03139_y.fits ... by semantics #this failed
# Trying to download preview in the best quality with #peview-image semantics
# <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-AG/AG03139_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-AG/AG03139_y.fits ... #preview-image
# is empty, skipping
# datalink table is empty, skipping
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-AG/AG03139_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-AG/AG03139_y.fits ... by semantics #preview-image failed
# Downloading plates/AG03139_pre.jpg_1958 ...
# plates/AG03139_pre.jpg_1958 saved
# Datalink do not provide #proc
# Trying to download whole fits image by #this semantics
# Downloading plates/AG03152_y.fits ...
# 404 Client Error: Not Found for url: https://www.plate-archive.org/files/DR3/scans/HAM-AG/AG03152_y.fits
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-AG/AG03152_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-AG/AG03152_y.fits ... by semantics #this failed
# Trying to download preview in the best quality with #peview-image semantics
# <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-AG/AG03152_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-AG/AG03152_y.fits ... #preview-image
# is empty, skipping
# datalink table is empty, skipping
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-AG/AG03152_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-AG/AG03152_y.fits ... by semantics #preview-image failed
# Downloading plates/AG03152_pre.jpg_1958 ...
# plates/AG03152_pre.jpg_1958 saved
# Datalink do not provide #proc
# Trying to download whole fits image by #this semantics
# Downloading plates/AG03170_y.fits ...
# 404 Client Error: Not Found for url: https://www.plate-archive.org/files/DR3/scans/HAM-AG/AG03170_y.fits
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-AG/AG03170_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-AG/AG03170_y.fits ... by semantics #this failed
# Trying to download preview in the best quality with #peview-image semantics
# <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-AG/AG03170_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-AG/AG03170_y.fits ... #preview-image
# is empty, skipping
# datalink table is empty, skipping
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-AG/AG03170_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-AG/AG03170_y.fits ... by semantics #preview-image failed
# Downloading plates/AG03170_pre.jpg_1958 ...
# plates/AG03170_pre.jpg_1958 saved
# cutout_156_48
# plates/fbs1247M_cor.fits is ready
# cutout_156_48
# plates/fbs1248M_cor.fits is ready
# Datalink do not provide #proc
# Trying to download whole fits image by #this semantics
# Downloading plates/KSz0407_x.fits ...
# 404 Client Error: Not Found for url: https://www.plate-archive.org/files/DR3/scans/HAM-KS/KSz0407_x.fits
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-KS/KSz0407_x.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-KS/KSz0407_x.fits ... by semantics #this failed
# Trying to download preview in the best quality with #peview-image semantics
# <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-KS/KSz0407_x.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-KS/KSz0407_x.fits ... #preview-image
# is empty, skipping
# datalink table is empty, skipping
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-KS/KSz0407_x.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-KS/KSz0407_x.fits ... by semantics #preview-image failed
# Downloading plates/KSz0407_pre.jpg_1976 ...
# plates/KSz0407_pre.jpg_1976 saved
# Datalink do not provide #proc
# Trying to download whole fits image by #this semantics
# Downloading plates/HS01338_y.fits ...
# 404 Client Error: Not Found for url: https://www.plate-archive.org/files/DR3/scans/HAM-HS/HS01338_y.fits
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-HS/HS01338_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-HS/HS01338_y.fits ... by semantics #this failed
# Trying to download preview in the best quality with #peview-image semantics
# <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-HS/HS01338_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-HS/HS01338_y.fits ... #preview-image
# is empty, skipping
# datalink table is empty, skipping
# Downloading <DALResultsTable length=2>
#                               ID                               ...
#                                                                ...
#                             object                             ...
# -------------------------------------------------------------- ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-HS/HS01338_y.fits ...
# ivo://org.gavo.dc/~?applause/q/DR3/scans/HAM-HS/HS01338_y.fits ... by semantics #preview-image failed
# Downloading plates/HS01338_pre.jpg_1986 ...
# plates/HS01338_pre.jpg_1986 saved
